# %%
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
all_comments = pd.read_csv('/.../all_comments.csv', lineterminator='\n')

# %%
train_set = all_comments.sample(n=4000, random_state=25)

# %%
train_set
# Out:
#                       publishedAt             updatedAt  likeCount  \
# 139443  2022-08-01 14:25:46+00:00  2022-08-01T14:25:46Z          0
# 150681  2020-11-29 22:48:14+00:00  2020-11-29T22:48:14Z          5
# 204632  2021-11-10 23:04:53+00:00  2021-11-10T23:05:42Z          0
# 9759    2019-10-17 18:17:59+00:00  2019-10-17T18:17:59Z          1
# 295681  2021-07-01 17:28:07+00:00  2021-07-01T17:28:07Z          3
# ...                           ...                   ...        ...
# 290926  2022-02-03 19:21:14+00:00  2022-02-03T19:21:14Z         11
# 175437  2021-12-03 03:24:26+00:00  2021-12-03T03:24:26Z          3
# 28929   2023-11-21 06:57:42+00:00  2023-11-21T06:57:42Z          0
# 116685  2023-03-03 11:44:14+00:00  2023-03-03T11:44:14Z          2
# 281429  2023-06-12 11:25:28+00:00  2023-06-12T11:25:28Z          0
#
#                                               textDisplay  \
# 139443  @@johnsmith-fk7fw istg americans have worms fo...
# ...

# %%
video_index_counts = train_set['video_index'].value_counts()

video_index_counts.head()
# Out:
# video_index
# 10     773
# 47     689
# 227    251
# 42     228
# 91     166
# Name: count, dtype: int64

# %%
train_set = train_set[['textDisplay']].copy()
train_set['label'] = pd.NA

# %%
train_set
# Out:
#                                               textDisplay label
# 139443  @@johnsmith-fk7fw istg americans have worms fo...   NaN
# 150681  Is this a good place to request an EE video on...   NaN
# 204632  I&#39;m dumbfounded at the 140 school district...   NaN
# 9759                                      We miss him too   NaN
# 295681  child labor was eradicated through left leanin...   NaN
# ...                                                   ...   ...
# 290926  Still, it beats the alternative. Equality for ...   NaN
# 175437    They&#39;re the ones responsible for this mess.   NaN
# 28929   @@kesk5619 the reason communism lost is becaus...   NaN
# 116685  Replace thugging with education.<br>Learn team...   NaN
# 281429  @@stephensmith799 And going by the crime rate ...   NaN
#
# [4000 rows x 2 columns]

# %%
train_set.to_excel('/.../train_set.xlsx', index=False, engine='openpyxl')

# %%
train_set = pd.read_excel('/.../train_set.xlsx')

# %%
train_set
# Out:
#                                             textDisplay  label
# 0     @@johnsmith-fk7fw istg americans have worms fo...    NaN
# 1     Is this a good place to request an EE video on...    NaN
# 2     I&#39;m dumbfounded at the 140 school district...    NaN
# 3                                       We miss him too    NaN
# 4     child labor was eradicated through left leanin...    NaN
# ...                                                 ...    ...
# 3995  Still, it beats the alternative. Equality for ...    NaN
# 3996    They&#39;re the ones responsible for this mess.    NaN
# 3997  @@kesk5619 the reason communism lost is becaus...    NaN
# 3998  Replace thugging with education.<br>Learn team...    NaN
# 3999  @@stephensmith799 And going by the crime rate ...    NaN
#
# [4000 rows x 2 columns]
